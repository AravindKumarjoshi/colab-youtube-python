# %% [markdown]
# <a href="https://colab.research.google.com/github/AravindKumarjoshi/colab-youtube-python/blob/main/my_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import requests

# %% [markdown]
# # Task
# Generate Python code to retrieve all video IDs from a YouTube playlist using the YouTube Data API. Explain how to obtain and use an API key securely.

# %% [markdown]
# ## Set up api key
#
# ### Subtask:
# Explain how to get a YouTube Data API key and securely store it in Colab.

# %% [markdown]
# **Reasoning**:
# Provide an explanation of how to obtain a YouTube Data API key and securely store it in Google Colab.

# %%
# Instructions on obtaining and storing a YouTube Data API key:

# 1. Obtain a YouTube Data API Key:
#    a. Go to the Google Cloud Console (console.cloud.google.com). You may need to log in or create an account.
#    b. Create a new project or select an existing one.
#    c. In the navigation menu, go to "APIs & Services" > "Library".
#    d. Search for "YouTube Data API v3" and select it.
#    e. Click the "Enable" button.
#    f. In the navigation menu, go to "APIs & Services" > "Credentials".
#    g. Click "Create Credentials" and select "API Key".
#    h. Your API key will be generated. Copy this key. You can restrict the key's usage (e.g., by IP address or HTTP referrer) for added security, which is highly recommended.

# 2. Securely Store the API Key in Google Colab:
#    a. Open your Google Colab notebook.
#    b. In the left sidebar, click the "Secrets" tab (it looks like a key). If you don't see it, you might need to enable it in the notebook settings (Notebook settings -> enable "Show the Secrets tab").
#    c. Click "Add new secret".
#    d. In the "Name" field, enter a descriptive name for your secret, such as `YOUTUBE_API_KEY`.
#    e. In the "Value" field, paste the API key you copied from the Google Cloud Console.
#    f. Ensure that the "Notebook access" toggle is enabled for your current notebook.
#    g. To access the secret in your code, you can use the `user_secrets` dictionary provided by Colab's `google.colab` library. For example:
#       from google.colab import userdata
#       api_key = userdata.get('YOUTUBE_API_KEY')
#    h. **IMPORTANT:** Never hardcode your API key directly in your notebook code. Using the Secrets feature keeps your key secure and prevents accidental exposure if you share your notebook.

# %% [markdown]
# ## Define api endpoint and parameters
#
# ### Subtask:
# Define the base URL for the `playlistItems` endpoint and specify the necessary parameters like `key`, `playlistId`, and `part`.

# %% [markdown]
# **Reasoning**:
# Define the base URL and the parameters dictionary for the API request as instructed.

# %%
from google.colab import userdata

base_url = 'https://www.googleapis.com/youtube/v3/playlistItems'

params = {
    'key': userdata.get('YOUTUBE_API_KEY'),
    'playlistId': 'PLdb6KKzTz-by4IuO4qsG8JZokr4ouvFH4', # Replace with an actual playlist ID
    'part': 'snippet',
    'maxResults': 180
}

# %% [markdown]
# ## Make api request
#
# ### Subtask:
# Generate code to make an HTTP GET request to the YouTube API using the `requests` library.

# %% [markdown]
# **Reasoning**:
# Generate code to make an HTTP GET request to the YouTube API using the `requests` library, check the response status code, and print an error message if the request was not successful.

# %%
video_ids = []
paged_token = None

while True:
  params['pageToken'] = paged_token
  base_url = 'https://www.googleapis.com/youtube/v3/playlistItems'
  response = requests.get(base_url, params=params)
  data = response.json()

    # Extract video IDs from current page and add to all_video_ids
  for item in data.get('items', []):
        # ... extraction logic ...
        snippet = item.get('snippet', {})
        resource_id = snippet.get('resourceId', {})
        video_id = resource_id.get('videoId')
        if video_id:
            video_ids.append(video_id)

  paged_token = data.get('nextPageToken')

  if not paged_token:
        break # Exit loop if no more pages

print(f"Total video IDs retrieved: {len(video_ids)}")

# if response.status_code != 200:
#     print(f"Error: API request failed with status code {response.status_code}")
#     print(f"Response text: {response.text}")


# if response.status_code == 200:
#     data = response.json()
#     for item in data.get('items', []):
#         snippet = item.get('snippet', {})
#         resource_id = snippet.get('resourceId', {})
#         video_id = resource_id.get('videoId')
#         if video_id:
#             video_ids.append(video_id)

# print(f"Found {len(video_ids)} video IDs.")
# if video_ids:
#     print("First 10 video IDs:", video_ids[:10])
# Out:
# Total video IDs retrieved: 175, RlUKQsbFX1c

# %% [markdown]
# ## Process api response
#
# ### Subtask:
# Generate code to parse the JSON response from the API and extract the video IDs from the playlist items.

# %% [markdown]
# **Reasoning**:
# Parse the JSON response and extract the video IDs as instructed.

# %% [markdown]
# ## Handle pagination
#
# ### Subtask:
# Explain how to handle pagination in the API response to retrieve all video IDs if the playlist has more items than the maximum per page.

# %%
import re
import requests
from google.colab import userdata

base_url_videos = 'https://www.googleapis.com/youtube/v3/videos'

# Assuming 'video_ids' is already populated from the previous step
# If not, you would need to run the previous steps to get the video_ids first.

# The YouTube Data API allows up to 50 video IDs per request.
# We'll process the video_ids in batches of 50.
batch_size = 50
pdf_urls = {} # Dictionary to store video ID and found PDF URLs

# Check if video_ids is defined and not empty
if 'video_ids' in locals() and video_ids:
    for i in range(0, len(video_ids), batch_size):
        batch_ids = video_ids[i:i + batch_size]
        # Join the batch_ids with commas for the API request
        video_ids_string = ','.join(batch_ids)

        params_videos = {
            'key': userdata.get('YOUTUBE_API_KEY'),
            'id': video_ids_string,
            'part': 'snippet' # We need the snippet part to get the description
        }

        response_videos = requests.get(base_url_videos, params=params_videos)
        data_videos = response_videos.json()

        if response_videos.status_code != 200:
            print(f"Error fetching video details: {response_videos.status_code}")
            print(f"Response text: {data_videos}")
            continue # Skip to the next batch if there's an error

        # Process the response and extract descriptions
        for item in data_videos.get('items', []):
            video_id = item.get('id')
            description = item.get('snippet', {}).get('description', '')

            # Use regular expressions to find the specific phrases and extract the URL that follows.
            # This regex looks for "Click here to download the PDFs of this series: " or "download the PDFs"
            # and then captures the URL that follows.
            # It assumes the URL is on the same line and starts with http or https.
            pdf_link_pattern = r"(?:Click here to download the PDFs of this series:|download the PDFs.*?)\s*(http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+)"
            found_links = re.findall(pdf_link_pattern, description)

            if found_links:
                # found_links will be a list of tuples, where each tuple is the captured group (the URL)
                # We want a list of just the URLs.
                pdf_urls[video_id] = [link for link in found_links]
                print(f"Found potential PDF links for video ID {video_id}: {pdf_urls[video_id]}")
            # else:
                # print(f"No specific PDF download phrase or link found for video ID {video_id}")

    print("\nSummary of video IDs and found potential PDF URLs:")
    if pdf_urls:
        for video_id, urls in pdf_urls.items():
            print(f"Video ID: {video_id}")
            if urls:
                for url in urls:
                    print(f"- {url}")
            else:
                print("  No potential PDF URLs found with the specified phrases.")
    else:
        print("No potential PDF URLs were found in any of the video descriptions.")

else:
    print("The 'video_ids' list is not populated. Please run the previous steps to get the video IDs.")

# %% [markdown]
# **Reasoning**:
# Explain how to handle pagination in the API response, covering the points outlined in the instructions.

# %%
# Explanation on handling pagination in the YouTube Data API:

# 1. API Result Limits:
#    The YouTube Data API limits the number of results returned per request for the playlistItems endpoint.
#    The default and maximum number of results per page is typically 50.

# 2. Checking for nextPageToken:
#    The API response includes a field called `nextPageToken` if there are more results available beyond the current page.
#    You can check for the presence of this key in the top level of the JSON response data.

# 3. Indication of More Results:
#    If the `nextPageToken` field exists and is not empty, it signifies that there are additional pages of results that can be retrieved.

# 4. Using the pageToken Parameter:
#    To fetch the next page of results, you need to include the `pageToken` parameter in your subsequent API request.
#    The value of the `pageToken` parameter for the next request should be the value of the `nextPageToken` obtained from the *previous* response.

# 5. Looping Through Pages:
#    You need to implement a loop that continues to make API requests as long as a `nextPageToken` is present in the response.
#    In each iteration of the loop, you update the `pageToken` parameter with the `nextPageToken` from the latest response and make a new request.
#    The loop terminates when an API response does not contain a `nextPageToken`, indicating that you have retrieved all the items in the playlist.

# 6. Accumulating Video IDs:
#    Inside the loop, after processing the response from each page and extracting the video IDs, you should append these IDs to a single list that exists outside the loop.
#    This list will accumulate all the video IDs from all the pages until the loop finishes.

# Example structure (conceptual):
# all_video_ids = []
# next_page_token = None
#
# while True:
#     params['pageToken'] = next_page_token # Update pageToken for the next request
#     response = requests.get(base_url, params=params)
#     data = response.json()
#
#     # Extract video IDs from current page and add to all_video_ids
#     for item in data.get('items', []):
#         # ... extraction logic ...
#         video_id = ...
#         if video_id:
#             all_video_ids.append(video_id)
#
#     next_page_token = data.get('nextPageToken')
#
#     if not next_page_token:
#         break # Exit loop if no more pages
#
# print(f"Total video IDs retrieved: {len(all_video_ids)}")

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   A YouTube Data API key is required to access playlist data and can be obtained through the Google Cloud Console.
# *   The `playlistItems` endpoint is used to retrieve items within a playlist.
# *   The necessary parameters for the API request include `key`, `playlistId`, and `part='snippet'`.
# *   The API response is in JSON format, and video IDs are nested within `items` -> `snippet` -> `resourceId` -> `videoId`.
# *   The API limits the number of results per request (typically 50), and pagination is handled using `nextPageToken` in the response and the `pageToken` parameter in subsequent requests.
# *   Securely storing the API key, for example, using Google Colab's Secrets feature, is crucial.
#
# ### Insights or Next Steps
#
# *   Implement the pagination logic in the code to ensure all video IDs are retrieved from playlists with more than 50 items.
# *   Add error handling for potential issues like invalid playlist IDs or API rate limits.

# %% [markdown]
# # Task
# Retrieve PDF URLs from the descriptions of YouTube videos using the YouTube Data API, given a list of video IDs.

# %% [markdown]
# ## Define api endpoint and parameters for videos
#
# ### Subtask:
# Define the base URL for the `videos` endpoint and specify the necessary parameters like `key`, `id`, and `part`.

# %% [markdown]
# **Reasoning**:
# Define the base URL and the parameters dictionary for the API request to the `videos` endpoint as instructed.

# %%
# import re
# import requests
# from google.colab import userdata

base_url_videos = 'https://www.googleapis.com/youtube/v3/videos'

# Assuming 'video_ids' is already populated from the previous step
# If not, you would need to run the previous steps to get the video_ids first.

# The YouTube Data API allows up to 50 video IDs per request.
# We'll process the video_ids in batches of 50.
batch_size = 50
pdf_urls = {} # Dictionary to store video ID and found PDF URLs

# Check if video_ids is defined and not empty
if 'video_ids' in locals() and video_ids:
    for i in range(0, len(video_ids), batch_size):
        batch_ids = video_ids[i:i + batch_size]
        # Join the batch_ids with commas for the API request
        video_ids_string = ','.join(batch_ids)

        params_videos = {
            'key': userdata.get('YOUTUBE_API_KEY'),
            'id': video_ids_string,
            'part': 'snippet' # We need the snippet part to get the description
        }

        response_videos = requests.get(base_url_videos, params=params_videos)
        data_videos = response_videos.json()

        if response_videos.status_code != 200:
            print(f"Error fetching video details: {response_videos.status_code}")
            print(f"Response text: {data_videos}")
            continue # Skip to the next batch if there's an error

        # Process the response and extract descriptions
        for item in data_videos.get('items', []):
            video_id = item.get('id')
            description = item.get('snippet', {}).get('description', '')

            # Use regular expressions to find URLs that start with "https://drive.google.com"
            drive_link_pattern = r"https://drive.google.com(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"
            found_links = re.findall(drive_link_pattern, description)

            if found_links:
                # found_links will be a list of the captured URLs
                pdf_urls[video_id] = found_links
                print(f"Found potential Drive links for video ID {video_id}: {pdf_urls[video_id]}")
            # else:
                # print(f"No Drive links found for video ID {video_id}")

    print("\nSummary of video IDs and found potential Drive URLs:")
    if pdf_urls:
        for video_id, urls in pdf_urls.items():
            print(f"Video ID: {video_id}")
            if urls:
                for url in urls:
                    print(f"- {url}")
            else:
                print("  No potential Drive URLs found.")
    else:
        print("No potential Drive URLs were found in any of the video descriptions.")

else:
    print("The 'video_ids' list is not populated. Please run the previous steps to get the video IDs.")
# Out:
# Found potential Drive links for video ID AHFBK0YDk3s: ['https://drive.google.com/uc?export=download&id=19yDmxmxk0Z78GZ_mJi5-vHx8qYIiBABF']
# Found potential Drive links for video ID 6T0NWKiXe4Y: ['https://drive.google.com/uc?export=download&id=1Gt_DOuJUrcqaoNYib2exqa0qRLLR5yMO']
# Found potential Drive links for video ID LIXZ2cuPv5c: ['https://drive.google.com/uc?export=download&id=1Ix2jqqgjEooSCNoJSn0b3YGQoy8prHB1']
# Found potential Drive links for video ID tv43okv6v1Y: ['https://drive.google.com/uc?export=download&id=1nKn3VYtJWtu6FH-QLIa2yLK35Kde4fUW']
# Found potential Drive links for video ID ITbbpElhGbM: ['https://drive.google.com/uc?export=download&id=1X8QafjJu2IGzWYKgy5My0xUdGylL_zkO']
# Found potential Drive links for video ID W1FKsIMipdw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID l6tZrRx1V8Q: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID BzLob23wqv8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID kp98sX96zDU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID sNzHmLiTrak: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID SIJwvsZo6TI: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID HCkCEZb_TeE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID JMNtViypSmo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID r_tdnThGC6E: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Srs-vGqgvPg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID GTOlVEugdTQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID C7A585p3ny8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID K_TqZ-A969g: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID obonh7ZNK0A: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID dusurutU7v4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID wzbpMMjdQ6M: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID xOMR9tFJkPw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 3mC3-n0kQ_M: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 7PKu6yzfol8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID VqXHQyCdvno: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Im8gGPymBww: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID CHDe6SoeinM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zwT7yi4IKu8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 02EIl2MePc8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID KZjTXv1cBH8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 7l8NyElR3zM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NrS9VVR0Vg8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID N1OTKAamZ3U: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Lx82PyuUNKE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID F5Cc2hqXF2M: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Fc9kTaqjJzA: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ErlVDkX_z6E: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zjSFGYEgSUY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID mPtWdscLPno: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID iuYw-YgrubU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID mGcj47rTmAc: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID y9jQEiGzFic: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID RtOp4e5TjiM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ad77eW2HIwY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Qa5uysKjb8M: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Tq1AtyYiE3o: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 63d_C6lfoAs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID FKzLXmEceLE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID enFioT-RL7o: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID nnS96nQW-9E: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Cjews-bPzjw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID sGvZPYUaHm0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID cnEvDsuVivo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 3_L-t9ynj_g: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID X8FVt4ihyeQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 4Y_isdkyPow: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Jz1lgARTdDk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Piwz6q7IVDc: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID qO8hCQEi6LY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Z-PbJktdS2o: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID uooXcBhZgSk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ho2o8HZh_lk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID E2hRNJgXcP0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID fE-oT3CNtEs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID WCcu0uIJwHE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID AWz5muXrDBE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID nKgjHV30xjw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID yCUXAfcO3q8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID o8rH2RlhCO4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 1-_4fgITuCs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID LweRflLvTUQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID vFQKJy0VxpA: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 7KIWmLvyW4c: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID eaLXKvw0HHI: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID uKajUceduzk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID eb-hy63OQLc: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zzCy1OlR25I: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID sM-r4WUBY_c: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Bv-f3n3-M9U: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID LXaeRvhRsFw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 8pyuVHIsRZE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID l4aKAEqDcX0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NUznYSymwtI: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID w6AGAnGmrhg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID cRm4SzO-_0I: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID BhMnp0XYdQE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NqJ4wkGqd3I: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID rb5UQ2Dv9mc: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID bCjNUXPPBNA: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 45zEWaDG0oQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID -5hUWoOg6no: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zcEEAOv6bfY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 8iH3aPju1qw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID P7yLzXsfBt0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID VLJXqJvxU9s: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID iMFCkYu85VU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ATDkUcn-U1Q: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID mJbi6eerFXk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID LVtmx0nZvXE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID fQGkMO8TzU4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID N2Bve2xhaPQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ELEyEyM7D20: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 5zZXb_BBPjQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID z3maEGCWbRA: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID qNl5NM_gQIU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID -xH5gel1Y1U: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID VLfeK8M-RQg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID gAH2oicg6cU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID DTlwP8g6Vb4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ePJY1LZ2SfQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Y8fFGz7_CLw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 64iMrIoonN8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID larlZFo_dbo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 2Z-9LzLLE7U: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Ov5hFDlAi1Y: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NXDhPbo69l8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID BV92Kzm8JD8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Jh78JVgQ-i4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID SK1q4NsK1u0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zvMM-bO9oiQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 6ySWxZbSlO0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID iwOi1wogqnU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NLsAu1o4nek: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID pTqd-KiU5zY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID -2izBQ_Ggm0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID RImhpMl_cV8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID UAI5OUdaV6o: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 27WdpJlTFMM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID c0h5pobFh9M: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 9w5uRnY7n5A: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID sfxEYtAaiZM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID aQYRXT5-13g: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 0oP-4oFcNzo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID e5zdtQbZ-xg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zG7t3u1Np3c: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID VyrOye8QElY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID UR5qc5x9kwQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Scnnpzl8vq8: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID WHM9NMu26qQ: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID G4S9F625SiM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID OO3Irm5jrT0: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zrNgBLQP1us: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID nXhlbPuqhCU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID TWGVGy1fV6Y: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID SAzvZ8wOCOw: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID q97lPTFiFP4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID TUk8kLdp7qM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID NMvevxykIFY: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 07Fa3o4N4zI: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID qtL-G67Tx50: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID qsi5FwKDa7g: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Nj_GAb5pXQg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID -dJkuLFNOss: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID T64PlV_7Xa4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 9mXxFJ9BW-c: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 5b-6G1srNGE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 19xnFEj2uRI: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID T-bQw1quluk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID LXKT5XUoOj4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID hsQagp8-xrg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID pkD-aERzBPE: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID glD78HLl6EU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID k-ElH4gMmhk: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID Ap10ICsZgSM: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID VPggsEFDmS4: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID WM0-GRhepHs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID RAZ9GPs0LNo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID DJCIGSQ5XHs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID ZWaAVe8ILBg: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID 6sPPLA_FDVU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID wFX5gu5_DTU: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID aGoQsrqNvTo: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID zVRBgckjwDs: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID vUxDyQHE-MA: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
# Found potential Drive links for video ID RlUKQsbFX1c: ['https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M']
#
# Summary of video IDs and found potential Drive URLs:
# Video ID: AHFBK0YDk3s
# - https://drive.google.com/uc?export=download&id=19yDmxmxk0Z78GZ_mJi5-vHx8qYIiBABF
# Video ID: 6T0NWKiXe4Y
# - https://drive.google.com/uc?export=download&id=1Gt_DOuJUrcqaoNYib2exqa0qRLLR5yMO
# Video ID: LIXZ2cuPv5c
# - https://drive.google.com/uc?export=download&id=1Ix2jqqgjEooSCNoJSn0b3YGQoy8prHB1
# Video ID: tv43okv6v1Y
# - https://drive.google.com/uc?export=download&id=1nKn3VYtJWtu6FH-QLIa2yLK35Kde4fUW
# Video ID: ITbbpElhGbM
# - https://drive.google.com/uc?export=download&id=1X8QafjJu2IGzWYKgy5My0xUdGylL_zkO
# Video ID: W1FKsIMipdw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: l6tZrRx1V8Q
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: BzLob23wqv8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: kp98sX96zDU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: sNzHmLiTrak
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: SIJwvsZo6TI
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: HCkCEZb_TeE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: JMNtViypSmo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: r_tdnThGC6E
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Srs-vGqgvPg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: GTOlVEugdTQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: C7A585p3ny8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: K_TqZ-A969g
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: obonh7ZNK0A
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: dusurutU7v4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: wzbpMMjdQ6M
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: xOMR9tFJkPw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 3mC3-n0kQ_M
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 7PKu6yzfol8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: VqXHQyCdvno
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Im8gGPymBww
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: CHDe6SoeinM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zwT7yi4IKu8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 02EIl2MePc8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: KZjTXv1cBH8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 7l8NyElR3zM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NrS9VVR0Vg8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: N1OTKAamZ3U
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Lx82PyuUNKE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: F5Cc2hqXF2M
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Fc9kTaqjJzA
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ErlVDkX_z6E
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zjSFGYEgSUY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: mPtWdscLPno
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: iuYw-YgrubU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: mGcj47rTmAc
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: y9jQEiGzFic
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: RtOp4e5TjiM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ad77eW2HIwY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Qa5uysKjb8M
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Tq1AtyYiE3o
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 63d_C6lfoAs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: FKzLXmEceLE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: enFioT-RL7o
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: nnS96nQW-9E
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Cjews-bPzjw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: sGvZPYUaHm0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: cnEvDsuVivo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 3_L-t9ynj_g
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: X8FVt4ihyeQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 4Y_isdkyPow
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Jz1lgARTdDk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Piwz6q7IVDc
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: qO8hCQEi6LY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Z-PbJktdS2o
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: uooXcBhZgSk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ho2o8HZh_lk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: E2hRNJgXcP0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: fE-oT3CNtEs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: WCcu0uIJwHE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: AWz5muXrDBE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: nKgjHV30xjw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: yCUXAfcO3q8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: o8rH2RlhCO4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 1-_4fgITuCs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: LweRflLvTUQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: vFQKJy0VxpA
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 7KIWmLvyW4c
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: eaLXKvw0HHI
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: uKajUceduzk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: eb-hy63OQLc
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zzCy1OlR25I
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: sM-r4WUBY_c
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Bv-f3n3-M9U
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: LXaeRvhRsFw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 8pyuVHIsRZE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: l4aKAEqDcX0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NUznYSymwtI
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: w6AGAnGmrhg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: cRm4SzO-_0I
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: BhMnp0XYdQE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NqJ4wkGqd3I
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: rb5UQ2Dv9mc
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: bCjNUXPPBNA
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 45zEWaDG0oQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: -5hUWoOg6no
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zcEEAOv6bfY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 8iH3aPju1qw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: P7yLzXsfBt0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: VLJXqJvxU9s
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: iMFCkYu85VU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ATDkUcn-U1Q
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: mJbi6eerFXk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: LVtmx0nZvXE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: fQGkMO8TzU4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: N2Bve2xhaPQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ELEyEyM7D20
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 5zZXb_BBPjQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: z3maEGCWbRA
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: qNl5NM_gQIU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: -xH5gel1Y1U
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: VLfeK8M-RQg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: gAH2oicg6cU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: DTlwP8g6Vb4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ePJY1LZ2SfQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Y8fFGz7_CLw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 64iMrIoonN8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: larlZFo_dbo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 2Z-9LzLLE7U
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Ov5hFDlAi1Y
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NXDhPbo69l8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: BV92Kzm8JD8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Jh78JVgQ-i4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: SK1q4NsK1u0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zvMM-bO9oiQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 6ySWxZbSlO0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: iwOi1wogqnU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NLsAu1o4nek
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: pTqd-KiU5zY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: -2izBQ_Ggm0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: RImhpMl_cV8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: UAI5OUdaV6o
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 27WdpJlTFMM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: c0h5pobFh9M
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 9w5uRnY7n5A
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: sfxEYtAaiZM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: aQYRXT5-13g
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 0oP-4oFcNzo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: e5zdtQbZ-xg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zG7t3u1Np3c
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: VyrOye8QElY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: UR5qc5x9kwQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Scnnpzl8vq8
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: WHM9NMu26qQ
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: G4S9F625SiM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: OO3Irm5jrT0
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zrNgBLQP1us
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: nXhlbPuqhCU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: TWGVGy1fV6Y
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: SAzvZ8wOCOw
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: q97lPTFiFP4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: TUk8kLdp7qM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: NMvevxykIFY
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 07Fa3o4N4zI
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: qtL-G67Tx50
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: qsi5FwKDa7g
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Nj_GAb5pXQg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: -dJkuLFNOss
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: T64PlV_7Xa4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 9mXxFJ9BW-c
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 5b-6G1srNGE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 19xnFEj2uRI
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: T-bQw1quluk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: LXKT5XUoOj4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: hsQagp8-xrg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: pkD-aERzBPE
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: glD78HLl6EU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: k-ElH4gMmhk
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: Ap10ICsZgSM
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: VPggsEFDmS4
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: WM0-GRhepHs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: RAZ9GPs0LNo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: DJCIGSQ5XHs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: ZWaAVe8ILBg
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: 6sPPLA_FDVU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: wFX5gu5_DTU
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: aGoQsrqNvTo
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: zVRBgckjwDs
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: vUxDyQHE-MA
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
# Video ID: RlUKQsbFX1c
# - https://drive.google.com/uc?export=download&id=16ySidvrxeB9s2MmoO9popqMw_LVB484M
